# %% [markdown]
# # 8.1 Find the Number of 1's, 4's, 7's, and 8's in Dispaly Output

# %%
#import packages
import pandas as pd
import numpy as np

# %%
#read in data

input = pd.read_csv('Day8_Input.txt', header=None, sep='|', names=['Signal', 'Output'])
input[['Space', 'O1', 'O2', 'O3', 'O4']] = input['Output'].str.split(' ', expand=True) #expand the output
input = input.drop('Space', axis=1) #drop extra column
input['Output'] = input['O1'] + ' ' + input['O2'] + ' ' + input['O3'] + ' ' + input['O4'] #combine for simple iteration

#take a look
input
# Out:
#                                                 Signal  \
# 0    beacf afbd bcead cgefa ecdbga efb gbfdeac ecgf...
# 1    cbdgef cdfageb cegbd fecba edgf dcfbe dbcafg d...
# 2    bgdcfa dgabf bfdec baefd abeg eda afcdge ea bf...
# 3    cfdabe fcgbe gcdeb ecdfgb bdc cdgf cd cfageb b...
# 4    eacgdfb fdbeca agedc cbedf dcfgab bgef gdf fdg...
# ..                                                 ...
# 195  cbedag edgca bfcagde gfbae gfdea df adfc dafce...
# 196  ebfc ef gecfad gfdcb egbad gfabcd ecgdafb feg ...
# 197  ce cefd cafdg cdgefa geacbd eca gcbfad gebfa a...
# 198  ceb edbgafc fabec cb dfagec fgbea daefcb efdca...
# 199  cgf aefbdgc gf bagf gedacf ecgfb cdfeb acgbe e...
#
#                          Output      O1       O2       O3       O4
# 0          bf efb bgecdfa egcfa      bf      efb  bgecdfa    egcfa
# 1       bgcdef dgbec bfeac fdeg  bgcdef    dgbec    bfeac     fdeg
# 2         efbad fbdea dae fagbd   efbad    fbdea      dae    fagbd
# 3          decbaf cdfg deabg cd  decbaf     cdfg    deabg       cd
# 4          gf acegd fdeabgc gfd      gf    acegd  fdeabgc      gfd
# ..                          ...     ...      ...      ...      ...
# 195      adecg gbafe acdbfeg df   adecg    gbafe  acdbfeg       df
# 196       aegdb bfged ef bafdgc   aegdb    bfged       ef   bafdgc
# 197           ecgfa cea defc ce   ecgfa      cea     defc       ce
# 198   bec eadfgbc degabc adgfce     bec  eadfgbc   degabc   adgfce
# 199  gf fbgcade cbegfda acbdfeg      gf  fbgcade  cbegfda  acbdfeg
#
# [200 rows x 6 columns]

# %%
# iterate through output displays to count number of 1's, 4's, 7's, and 8's
counter = 0 #initialize counter to count 1's, 4's, 7's, and 8's
for entry in input['Output']:
    for word in entry.split():
        if len(word) == 2 or len(word) == 4 or len(word) == 3 or len(word) == 7: #these are the unique lengths
            counter += 1
#check out the answer
counter
# Out:
# 488

# %%
def find_nums(nums):
    n1 = [x for x in nums if len(x) == 2][0]
    n4 = [x for x in nums if len(x) == 4][0]
    n7 = [x for x in nums if len(x) == 3][0]
    n8 = [x for x in nums if len(x) == 7][0]
    n9 = [x for x in nums if len(x) == 6 and all(y in x for y in n4)][0]
    n0 = [x for x in nums if len(x) == 6 and x != n9 and all(y in x for y in n1)][0]
    n6 = [x for x in nums if len(x) == 6 and x != n9 and x != n0][0]
    n3 = [x for x in nums if len(x) == 5 and all(y in x for y in n1)][0]
    n5 = [x for x in nums if len(x) == 5 and x != n3 and all(y in n9 for y in x)][0]
    n2 = [x for x in nums if len(x) == 5 and x != n3 and x != n5][0]
    return [n0, n1, n2, n3, n4, n5, n6, n7, n8, n9]


data = open("Day8_Input.txt").read().strip().split("\n")
lines = [[["".join(sorted(z)) for z in y.split()] for y in x.split(" | ")] for x in data]
p1 = p2 = 0
for nums, digits in lines:
    nums = find_nums(nums)
    p1 += sum(1 for x in digits if x in [nums[y] for y in [1, 4, 7, 8]])
    p2 += int("".join([str(nums.index(x)) for x in digits]))
print(f"Part 1: {p1}")
print(f"Part 2: {p2}")
# Out:
# Part 1: 488
# Part 2: 1040429

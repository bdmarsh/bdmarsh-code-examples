# %%
#import packages

import numpy as np

# %%
list2d = []

with open('Day9_Input.txt', 'r') as f:
    for line in f.readlines():
        list2d.append(list(line.rstrip('\n')))

# %%
arr = np.array(list2d, dtype='int32')

# %%
shape_min = 0
shape_max = arr.shape[0] - 1

# %%
counter = 0
risk_level = 0
for i in range(shape_max+1):
    for j in range(shape_max+1):
        if i == j == shape_min:
            if arr[i][j] < arr[i+1][j] and arr[i][j] < arr[i][j+1]:
                print(arr[i][j])
                risk_level += arr[i][j]+1
                print(risk_level)
                
        elif i == shape_min and j != shape_max:
            if arr[i][j] < arr[i][j-1] and arr[i][j] < arr[i][j+1] and arr[i][j] < arr[i+1][j]:
                print(arr[i][j])
                risk_level += arr[i][j]+1
                print(risk_level)
        
        elif i == shape_min and j == shape_max:
            if arr[i][j] < arr[i][j-1] and arr[i][j] < arr[i+1][j]:
                print(arr[i][j])
                risk_level += arr[i][j]+1
                print(risk_level)
            
        elif i != shape_max and j == shape_min:
            if arr[i][j] < arr[i-1][j] and arr[i+1][j] and arr[i][j] < arr[i][j+1]:
                print(arr[i][j])
                risk_level += arr[i][j]+1
                print(risk_level)
            
        elif i == shape_max and j == shape_min:
            if arr[i][j] < arr[i-1][j] and arr[i][j] < arr[i][j+1]:
                print(arr[i][j])
                risk_level += arr[i][j]+1
                print(risk_level)
                
        elif i == shape_max and j != shape_max:
            if arr[i][j] < arr[i][j-1] and arr[i][j] < arr[i-1][j] and arr[i][j] < arr[i][j+1]:
                print(arr[i][j])
                risk_level += arr[i][j]+1
                print(risk_level)
        
        elif i != shape_max and j == shape_max:
            if arr[i][j] < arr[i-1][j] and arr[i][j] < arr[i+1][j] and arr[i][j] < arr[i][j-1]:
                print(arr[i][j])
                risk_level += arr[i][j]+1
                print(risk_level)
                
        elif i == shape_max and j == shape_max:
            if arr[i][j] < arr[i][j-1] and arr[i][j] < arr[i-1][j]:
                print(arr[i][j])
                risk_level += arr[i][j]+1
                print(risk_level)
                
        else:
            if arr[i][j] < arr[i][j-1] and arr[i][j] < arr[i][j+1] and arr[i][j] < arr[i-1][j] and arr[i][j] < arr[i+1][j]:
                print(arr[i][j])
                risk_level += arr[i][j]+1
                print(risk_level)
risk_level
# Out:
# 5
# 6
# 4
# 11
# 0
# 12
# 0
# 13
# 0
# 14
# 0
# 15
# 1
# 17
# 1
# 19
# 0
# 20
# 0
# 21
# 0
# 22
# 0
# 23
# 1
# 25
# 1
# 27
# 5
# 33
# 2
# 36
# 0
# 37
# 0
# 38
# 2
# 41
# 1
# 43
# 0
# 44
# 1
# 46
# 1
# 48
# 5
# 54
# 0
# 55
# 0
# 56
# 3
# 60
# 0
# 61
# 0
# 62
# 3
# 66
# 0
# 67
# 0
# 68
# 0
# 69
# 3
# 73
# 0
# 74
# 0
# 75
# 5
# 81
# 0
# 82
# 1
# 84
# 0
# 85
# 6
# 92
# 2
# 95
# 0
# 96
# 0
# 97
# 2
# 100
# 5
# 106
# 0
# 107
# 4
# 112
# 2
# 115
# 3
# 119
# 3
# 123
# 0
# 124
# 3
# 128
# 3
# 132
# 0
# 133
# 4
# 138
# 1
# 140
# 0
# 141
# 2
# 144
# 0
# 145
# 0
# 146
# 0
# 147
# 0
# 148
# 4
# 153
# 1
# 155
# 4
# 160
# 2
# 163
# 0
# 164
# 0
# 165
# 0
# 166
# 0
# 167
# 0
# 168
# 3
# 172
# 0
# 173
# 1
# 175
# 3
# 179
# 0
# 180
# 0
# 181
# 0
# 182
# 2
# 185
# 4
# 190
# 0
# 191
# 6
# 198
# 1
# 200
# 1
# 202
# 0
# 203
# 2
# 206
# 0
# 207
# 0
# 208
# 0
# 209
# 0
# 210
# 0
# 211
# 1
# 213
# 0
# 214
# 1
# 216
# 4
# 221
# 4
# 226
# 4
# 231
# 2
# 234
# 3
# 238
# 1
# 240
# 1
# 242
# 4
# 247
# 3
# 251
# 0
# ...

# %%
shape_max
# Out:
# 99

# %%
risk_level = 0

for i in range(100):
    for j in range(100):
        if i == j == 0:
            if arr[i][j] < arr[i][j+1] and arr[i][j] < arr[i+1][j]:
                risk_level += arr[i][j]+1 
        elif i == 0 and j < 99:
            if arr[i][j] < arr[i][j-1] and arr[i][j] < arr[i][j+1] and arr[i][j] < arr[i+1][j]:
                risk_level += arr[i][j]+1 
        elif i == 0 and j == 99:
            if arr[i][j] < arr[i][j-1] and arr[i][j] < arr[i+1][j]:
                risk_level += arr[i][j]+1 
        elif j == 0 and i < 99:
            if arr[i][j] < arr[i-1][j] and arr[i][j] < arr[i][j+1] and arr[i][j] < arr[i+1][j]:
                risk_level += arr[i][j]+1
        elif j == 0 and i == 99:
            if arr[i][j] < arr[i-1][j] and arr[i][j] < arr[i][j+1]:
                risk_level += arr[i][j]+1
        elif i == 99 and j < 99:
            if arr[i][j] < arr[i][j-1] and arr[i][j] < arr[i-1][j] and arr[i][j] < arr[i][j+1]:
                risk_level += arr[i][j]+1
        elif i == 99 and j == 99:
            if arr[i][j] < arr[i][j-1] and arr[i][j] < arr[i-1][j]:
                risk_level += arr[i][j]+1
        elif j == 99 and i < 99:
            if arr[i][j] < arr[i][j-1] and arr[i][j] < arr[i-1][j] and arr[i][j] < arr[i+1][j]:
                risk_level += arr[i][j]+1
        elif i > 0 and i < 99 and j > 0 and j < 99:
            if arr[i][j] < arr[i-1][j] and arr[i][j] < arr[i+1][j] and arr[i][j] < arr[i][j-1] and arr[i][j] < arr[i][j+1]:
                risk_level += arr[i][j]+1
        else:
            print(f'Whoops! Forgot about array index ({i},{j})')
risk_level
# Out:
# 537

# %%
for i in range(100):
    for j in range(100):
        if low_point(i,j)==True:
            basin_size = 1
            if i == j == 0:
            


#function to determine if a point is a low point
def low_point(i,j):
    is_low = False
    if i == j == 0:
        if arr[i][j] < arr[i][j+1] and arr[i][j] < arr[i+1][j]:
            is_low = True
    elif i == 0 and j < 99:
        if arr[i][j] < arr[i][j-1] and arr[i][j] < arr[i][j+1] and arr[i][j] < arr[i+1][j]:
            is_low = True
    elif i == 0 and j == 99:
        if arr[i][j] < arr[i][j-1] and arr[i][j] < arr[i+1][j]:
            is_low = True
    elif j == 0 and i < 99:
        if arr[i][j] < arr[i-1][j] and arr[i][j] < arr[i][j+1] and arr[i][j] < arr[i+1][j]:
            is_low = True
    elif j == 0 and i == 99:
        if arr[i][j] < arr[i-1][j] and arr[i][j] < arr[i][j+1]:
            is_low = True
    elif i == 99 and j < 99:
        if arr[i][j] < arr[i][j-1] and arr[i][j] < arr[i-1][j] and arr[i][j] < arr[i][j+1]:
            is_low = True
    elif i == 99 and j == 99:
        if arr[i][j] < arr[i][j-1] and arr[i][j] < arr[i-1][j]:
            is_low = True
    elif j == 99 and i < 99:
        if arr[i][j] < arr[i][j-1] and arr[i][j] < arr[i-1][j] and arr[i][j] < arr[i+1][j]:
            is_low = True
    elif i > 0 and i < 99 and j > 0 and j < 99:
        if arr[i][j] < arr[i-1][j] and arr[i][j] < arr[i+1][j] and arr[i][j] < arr[i][j-1] and arr[i][j] < arr[i][j+1]:
            is_low = True
    else:
        print(f'Whoops! Forgot about array index ({i},{j})')
    return is_low

# %%
low_point(2,3)
# Out:
# True
